# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
def read(url):
    img= cv.cvtColor(cv.imread(url),cv.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis("off")
    return img
img=read("face.jpg")

# %%
def pyrDown(img):
    imgc=img.copy()
    for i in range(2):
        imgc= cv.pyrDown(imgc)
        print(imgc.shape)
        plt.imshow(imgc)
        plt.show()

pyrDown(img)
# Out:
# (203, 175, 3)
# (102, 88, 3)
